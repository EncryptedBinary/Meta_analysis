# %% [markdown]
# # Package

# %% [markdown]
# # Install packages

# %%
# !pip install transformers trl accelerate torch bitsandbytes peft langchain datasets -qU

# %% [markdown]
# # Initialization

# %%
import pandas as pd
import os
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer, GenerationConfig, LlamaForCausalLM, LlamaTokenizer
from sklearn.model_selection import train_test_split
import transformers
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
import copy
import datasets
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
from trl import SFTTrainer

# %% [markdown]
# # Specify the path to your Excel file

# %%
# Train set
PATH = "/kaggle/input/465analysisis/Our_trainset.xlsx"

try:
    trainset= pd.read_excel(PATH)

    print(trainset.head())

except Exception as e:
    print(f"Error loading dataset: {e}")

# %%
# Test Set
PATH = "/kaggle/input/465analysisis/Our_testset.xlsx"

try:
    testset = pd.read_excel(PATH)

    print(testset.head())

except Exception as e:
    print(f"Error loading dataset: {e}")

# %%
# Validation Set
PATH = "/kaggle/input/465analysisis/Our_validationset.xlsx"

try:
    validationset = pd.read_excel(PATH)

    print(validationset.head())

except Exception as e:
    print(f"Error loading dataset: {e}")

# %% [markdown]
# # Chunk-based Pre-Processing

# %%
import pandas as pd
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Instantiate RecursiveCharacterTextSplitter with custom parameters
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,
    chunk_overlap=200,
    length_function=len,
    #separators=['\n\n','MP:', '\n', ' ', '']
)

# Function to split text into chunks using the text splitter
def split_text_into_chunks(text):
    return text_splitter.split_text(text)

# %% [markdown]
# # Create a list to store chunked data

# %%
# Train Data
train_df = pd.DataFrame({"Paper": trainset["Main_Paper"], "Meta_Paper": trainset["SP"]})

chunked_train_data = {"Paper": [], "Meta_Paper": []}

for i, row in train_df.iterrows():
    context = row["Meta_Paper"]
    label = row["Paper"]
    #print(len(context))
    
    # Split the context into overlapping chunks
    chunks = split_text_into_chunks(context)
    for chunk in chunks:
        chunked_train_data["Paper"].append(label)
        chunked_train_data["Meta_Paper"].append(chunk)

# Create a new DataFrame with the chunked data
chunked_train_df = pd.DataFrame(chunked_train_data)

# %%
chunked_train_df
# Out:
#                                                   Paper  \
# 0     Background  The available evidence about the p...
# 1     Background  The available evidence about the p...
# 2     Background  The available evidence about the p...
# 3     Background  The available evidence about the p...
# 4     Background  The available evidence about the p...
# ...                                                 ...
# 3835  Available  on the association between the Medi...
# 3836  The effective management of the 33 million chi...
# 3837  The effective management of the 33 million chi...
# 3838  The effective management of the 33 million chi...
# 3839  The effective management of the 33 million chi...
#
#                                              Meta_Paper
# 0     MP: ObjectiveSeveral randomized controlled tri...
# 1     hormonal and inflammatory parameters, or can i...
# 2     and synbiotics supplementation in lipid profil...
# 3     and meta-analysis. Mean Difference (MD) was po...
# 4     on homeostatic model assessment-insulin resist...
# ...                                                 ...
# 3835  incidents, histologically confirmed gastric ca...
# 3836  MP: Despite the decreasing rate of under nutri...
# 3837  No adverse reactions were observed. There were...
# 3838  Three-factor analysis of covariance of the eff...
# 3839  at least one episode of SAM (MUAC <11cm and/or...
#
# [3840 rows x 2 columns]

# %%
# Validation Data
val_df = pd.DataFrame({"Paper": validationset["Main_Paper"], "Meta_Paper": validationset["SP"]})


chunked_val_data = {"Paper": [], "Meta_Paper": []}

for i, row in val_df.iterrows():
    context = row["Meta_Paper"]
    label = row["Paper"]

    # Split the context into overlapping chunks
    chunks = split_text_into_chunks(context)
    for chunk in chunks:
        chunked_val_data["Paper"].append(label)
        chunked_val_data["Meta_Paper"].append(chunk)

# Create a new DataFrame with the chunked data
chunked_val_df = pd.DataFrame(chunked_val_data)

# %%
# test data
test_df = pd.DataFrame({"Paper": testset["Main_Paper"], "Meta_Paper": testset["SP"]})

chunked_test_data = {"Paper": [], "Meta_Paper": []}

for i, row in test_df.iterrows():
    context = row["Meta_Paper"]
    label = row["Paper"]

    # Split the context into overlapping chunks
    chunks = split_text_into_chunks(context)
    for chunk in chunks:
        chunked_test_data["Paper"].append(label)
        chunked_test_data["Meta_Paper"].append(chunk)

# Create a new DataFrame with the chunked data
chunked_test_df = pd.DataFrame(chunked_test_data)

# %%
trainset = datasets.Dataset.from_dict(chunked_train_df)
valset = datasets.Dataset.from_dict(chunked_val_df)
testset = datasets.Dataset.from_dict(chunked_test_df)

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()

# %% [markdown]
# # Load Model with QLoRA

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

nf4_config = BitsAndBytesConfig(
   load_in_4bit=True,
   bnb_4bit_quant_type="nf4",
   bnb_4bit_use_double_quant=True,
   bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(
    "mistralai/Mistral-7B-Instruct-v0.1",
    device_map='auto',
    quantization_config=nf4_config,
    use_cache=False
)

tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-v0.1")

tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %% [markdown]
# # Initialize Instruction based Fine-tuning

# %%
DEFAULT_SYSTEM_PROMPT = """
Given a collection of abstracts from papers used in various medical fields, generate a meta-analysis abstract summarizing the key findings of those abstracts and provide numerical values or statistical information for specific observations that are commonly reported in the provided abstracts. Some provided abstracts may have chunks, so maintain information similarities.
""".strip()

# %%
from trl import SFTTrainer, DataCollatorForCompletionOnlyLM

def formatting_prompts_func(example):
    output_texts = []
    for i in range(len(example['Meta_Paper'])):
        text = f"### {DEFAULT_SYSTEM_PROMPT},### Abstracts: {example['Meta_Paper'][i]}  \n ### Meta-Analysis Abstract: {example['Paper'][i]}"
        

        output_texts.append(text)
    return output_texts

# %%
from peft import AutoPeftModelForCausalLM, LoraConfig, get_peft_model, prepare_model_for_kbit_training

peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=64,
    bias="none",
    task_type="CAUSAL_LM"
)

# %%
model = prepare_model_for_kbit_training(model)
model = get_peft_model(model, peft_config)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def softmax_selection(predictions, temperature=1.0, dim=-1):
    """
    Apply softmax to model predictions and sample a token based on the resulting probabilities.

    Args:
        predictions (torch.Tensor): The tensor containing the raw predictions from the model.
        temperature (float): Temperature parameter to adjust the sharpness of the probability distribution.
                              A lower temperature makes the distribution sharper.

    Returns:
        torch.Tensor: Tensor containing the selected token IDs.
    """
   # print(predictions.dim())
    if predictions.dim() > 2:
        predictions = predictions.view(-1, predictions.size(-1))
    # Apply softmax with temperature
    probs = F.softmax(predictions / temperature, dim=-1)
  

    # Sampling a token based on the probabilities
    sampled_tokens = torch.multinomial(probs, 1)

    return sampled_tokens

# %%
def quantities(decoded_predictions, decoded_labels):
    """
    Extract quantities from decoded predictions and labels.

    Args:
        decoded_predictions (list): List of decoded predictions.
        decoded_labels (list): List of decoded labels.

    Returns:
        tuple: A tuple containing lists of predicted quantities and actual quantities.
    """
    predicted_quantities = []
    actual_quantities = []

    for prediction, label in zip(decoded_predictions, decoded_labels):
        # Placeholder: Extracting the first number encountered in the decoded strings
        predicted_quantity = extract_quantity(prediction)
        actual_quantity = extract_quantity(label)
        predicted_quantities.append(predicted_quantity)
        actual_quantities.append(actual_quantity)

    return predicted_quantities, actual_quantities

def extract_quantity(text):
    """
    Extract the first numeric value from a string.

    Args:
        text (str): Input string.

    Returns:
        float: Extracted numeric value or NaN if no numeric value found.
    """
    import re
    # Regular expression to match numeric values
    numeric_pattern = re.compile(r'[-+]?[0-9]*\.?[0-9]+')
    # Search for numeric values in the text
    match = re.search(numeric_pattern, text)
    if match:
        # Extract and convert the first numeric value found
        return float(match.group())
    else:
        # Return NaN if no numeric value found
        return float('nan')

# %%
from sklearn.model_selection import train_test_split
import datasets
#dataset['tokenized_label'] = llama_tokenizer(dataset['Label'], return_tensors='pt')
trainset, testset = train_test_split(
    dataset,
    test_size=0.2
)
trainset = datasets.Dataset.from_dict(trainset)
testset = datasets.Dataset.from_dict(testset)
type(trainset)

# %% [markdown]
# # Inverse Cosine Distance (ICD) Loss function implementation

# %%
class CustomSFTTrainer(SFTTrainer):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
    def compute_loss(self, model, inputs, return_outputs=False):
        # Extract and remove labels from inputs
        labels = inputs.get("labels")
        
        # Forward pass
        outputs = model(**inputs)
        logits = outputs.logits  # Assuming the model outputs logits
        
        # Ensure logits and labels are float tensors
        logits = logits.float()
        labels = labels.float()
        
        # Reshape logits and labels
        logits = logits.view(logits.size(0), logits.size(1), -1)  
        labels = labels.view(labels.size(0), labels.size(1), -1)  
        
        # Normalize embeddings for cosine similarity
        logits = F.normalize(logits, p=2, dim=-1)
        labels = F.normalize(labels, p=2, dim=-1)

        # Calculate cosine similarity
        cosine_sim = torch.cosine_similarity(logits, labels, dim=-1)
        
        # Calculate loss using inverse of cosine similarity with epsilon for numerical stability
        epsilon = torch.tensor(1e-8, device=logits.device)
        loss = torch.mean(1 / (cosine_sim + epsilon))

        return (loss, outputs) if return_outputs else loss

# %% [markdown]
# # Training

# %%
# Loading LORA weights
base_model.config.use_cache = False

from peft import prepare_model_for_kbit_training
PATH1 = "/finetuned_llama2_cosine_sim_p1"

from peft import PeftModel, PeftConfig
base_model = PeftModel.from_pretrained(base_model, PATH1)
# ---- ending LORA weights -----

# Training Params
train_params = TrainingArguments(
    per_device_train_batch_size=2,
    gradient_accumulation_steps=1,
    fp16=False,
    max_grad_norm=0.3,
    num_train_epochs=2,
    evaluation_strategy="steps",
    eval_steps=0.2,
    warmup_ratio=0.05,
    save_strategy="epoch",
    group_by_length=True,
    save_safetensors=True,
    lr_scheduler_type="constant",
    output_dir="./results_modified_test",
    #num_train_epochs=1,
    #per_device_train_batch_size=2,
    #gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=2,
    logging_steps=2,
    learning_rate=2e-4,
    weight_decay=0.001,
    #fp16=False,
    bf16=False,
    #max_grad_norm=0.3,
    max_steps=-1,
    #warmup_ratio=0.05,
    #group_by_length=True,
    #lr_scheduler_type="constant",
    #report_to="wandb",
    # push to hub parameters,
   # push_to_hub=True,
)




# Trainer
fine_tuning = CustomSFTTrainer(
    model=base_model,
    train_dataset=trainset,
    eval_dataset = valset,
    peft_config=peft_parameters,
    # dataset_text_field=train_dataset["Statement"],
    tokenizer=llama_tokenizer,
    args=train_params,
    #max_seq_length = 2048,
    formatting_func=formatting_prompts_func,
    # data_collator=collator,
)

# %%
fine_tuning.train()
# Out:
# You are using 8-bit optimizers with a version of `bitsandbytes` < 0.41.1. It is recommended to update your version as a major bug has been fixed in 8-bit optimizers.
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: jbas3235. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240303_031946-o7cawmot</code>
# Syncing run <strong><a href='https://wandb.ai/jbas3235/llama2_465finetune22/runs/o7cawmot' target="_blank">honest-yogurt-1</a></strong> to <a href='https://wandb.ai/jbas3235/llama2_465finetune22' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jbas3235/llama2_465finetune22' target="_blank">https://wandb.ai/jbas3235/llama2_465finetune22</a>
#  View run at <a href='https://wandb.ai/jbas3235/llama2_465finetune22/runs/o7cawmot' target="_blank">https://wandb.ai/jbas3235/llama2_465finetune22/runs/o7cawmot</a>
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /opt/conda/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='3840' max='3840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3840/3840 10:37:34, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>768</td>
#       <td>1.045200</td>
#       <td>0.970265</td>
#     </tr>
#     <tr>
#       <td>1536</td>
#       <td>1.042100</td>
#       <td>0.967326</td>
#     </tr>
#     <tr>
#       <td>2304</td>
#       <td>1.038000</td>
#       <td>0.964995</td>
#     </tr>
#     <tr>
#       <td>3072</td>
#       <td>1.039200</td>
#       <td>0.964744</td>
#     </tr>
#     <tr>
#       <td>3840</td>
#       <td>0.895600</td>
#       <td>0.964325</td>
#     </tr>
#   </tbody>
# </table><p>
# /opt/conda/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# TrainOutput(global_step=3840, training_loss=1.0367341736331581, metrics={'train_runtime': 38294.4796, 'train_samples_per_second': 0.201, 'train_steps_per_second': 0.1, 'total_flos': 1.5332062395777024e+17, 'train_loss': 1.0367341736331581, 'epoch': 2.0})

# %%
fine_tuning.save_model("finetuned_llama2_cosine_sim_p1")

# %%
fine_tuning.model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): Linear4bit(
#                 in_features=4096, out_features=4096, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=4, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=4, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (v_proj): Linear4bit(
#                 in_features=4096, out_features=4096, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=4, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=4, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#               (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#               (act_fn): SiLUActivation()
#             )
#             (input_layernorm): LlamaRMSNorm()
#             (post_attention_layernorm): LlamaRMSNorm()
#           )
#         )
#         (norm): LlamaRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %% [markdown]
# # Meta-Analysis Generation

# %%
def summarize(text: str):
    inputs = llama_tokenizer(text, return_token_type_ids=False,return_tensors="pt").to("cuda")
#     inputs_length = len(inputs["input_ids"][0])
    with torch.inference_mode():
        outputs = base_model.generate(**inputs, max_new_tokens=1024, do_sample=True, temperature=0.7)

#         answer_tokens = outputs[:, inputs.input_ids.shape[1] :]
        decoded_output = llama_tokenizer.batch_decode(outputs, skip_special_tokens=True)

#         output_text = llama_tokenizer.decode(answer_tokens[0], skip_special_tokens=True).strip()
    return decoded_output

# %%
from peft import prepare_model_for_kbit_training

# %%
from peft import PeftModel, PeftConfig

# %%
output_dir="/kaggle/working/finetuned_llama2_cosine_sim_p1"

# %%
model_t = PeftModel.from_pretrained(base_model, output_dir)

# %%
# Initialize an empty list to store rows
rows = []

# Iterate over the texts in testset['Meta_Paper']
for i in range(len(testset['Meta_Paper'])):
    text = f"### {DEFAULT_SYSTEM_PROMPT},### Example Abstracts: {testset['Meta_Paper'][i]}  \n ### Meta-Analysis Abstract: "
    processed_output = summarize(text)
    
    # Extract the abstract from processed_output list
    abstract = ""
    for item in processed_output:
        if '### Meta-Analysis Abstract:' in item:
            abstract = item.split('### Meta-Analysis Abstract:')[1].strip()
            break
            
    print(i)
    print(abstract)
    # Append the "Meta_Paper" value and its processed output as a tuple to the rows list
    rows.append((testset['Meta_Paper'][i], testset['Paper'][i], abstract))

# Create a DataFrame from the rows list
df = pd.DataFrame(rows, columns=['Meta_Paper', 'Ground Truth', 'Processed Output'])

# Print or use the DataFrame as needed
print(df)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1417: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# 0
# The present meta-analysis aimed to summarize the key findings of the provided abstracts related to the efficacy and safety of therapeutic plasma exchange (TPE) in critically ill COVID-19 patients. A total of 87 abstracts were included in the analysis. The primary outcome measures were 35-day mortality and TPE safety. Secondary outcomes included days on mechanical ventilation (MV), intensive care unit (ICU) length of stay (LOS), clinical recovery (as measured by SOFA score), and various inflammatory biomarkers. The results showed that TPE was associated with improved clinical recovery (as measured by SOFA score) and reduced days on MV and ICU LOS. However, there was no significant difference in 35-day mortality between the TPE and standard treatment groups. The study found that TPE was associated with increased lymphocytes and ADAMTS-13 activity and decreased serum lactate, lactate dehydrogenase, ferritin, D-dimers, and interleukin-6. Multivariable regression analysis identified several predictors of 35-day mortality, including PaO2/FiO2 ratio, ADAMTS-13 activity, and pulmonary embolism. Post-hoc analysis revealed a significant reduction in SOFA score for TPE patients. In conclusion, TPE may have a beneficial effect on clinical recovery in critically ill COVID-19 patients, but no significant difference in 35-day mortality compared to standard treatment. Further research is needed to confirm these findings and explore the potential benefits and risks of TPE in COVID-19 patients.  Key Findings:  • TPE was associated with improved clinical recovery (as measured by SOFA score) and reduced days on MV and ICU LOS. • There was no significant difference in 35-day mortality between the TPE and standard treatment groups. • TPE was associated with increased lymphocytes and ADAMTS-13 activity and decreased serum lactate, lactate dehydrogenase, ferritin, D-dimers, and interleukin-6. • Multivariable regression analysis identified several predictors of 35-day mortality, including PaO2/FiO2 ratio, ADAMTS-13 activity, and pulmonary embolism. • Post-hoc analysis revealed a significant reduction in SOFA score for TPE patients.  Statistical Information:  • 35-day mortality: TPE, 20.9% (95% CI, 15.5–28.3%); standard treatment, 34.1% (95% CI, 27.2–41.3%). • Days on MV: TPE, 10.3 (95% CI, 7.6–13.0); standard treatment, 14.3 (95% CI, 10.9–17.7). • ICU LOS: TPE, 8.0 (95% CI, 5.9–10.1); standard treatment, 12.7 (95% CI, 9.8–15.6). • SOFA score at day 35: TPE, –2.4 (95% CI, –3.4 to –1.4); standard treatment, –2.0 (95% CI, –3.2 to –1.1). • Lymphocyte count at day 35: TPE, 1.1 (95% CI, 0.7–1.5) x 10^9/L; standard treatment, 0.7 (95% CI, 0.4–1.0) x 10^9/L. • ADAMTS-13 activity at day 35: TPE, 80.0 (95% CI, 68.6–91.4); standard treatment, 72.9 (95% CI, 60.9–84.8). • Ferritin level at day 35: TPE, 331.0 (95% CI, 263.8–400.2) ng/mL; standard treatment, 308.2 (95% CI, 236.4–380.0) ng/mL. • D-dimers level at day 35: TPE, 1.2 (9
# 1
# The provided abstracts highlight the potential benefits of therapeutic plasma exchange (TPE) in the treatment of Coronavirus disease-2019 (COVID-19). Numerous studies have demonstrated improved overall survival, reduced duration of hospitalization, and accelerated resolution of cytokine storm in patients treated with TPE compared to those on standard care. For instance, in a retrospective propensity score-matched analysis of 280 hospitalized patients with COVID-19 and cytokine release syndrome (CRS), TPE was associated with a significantly higher overall survival rate at 28 days (91.1% vs. 61.5%, p<0.001). Additionally, TPE was found to reduce the median duration of hospitalization by 5 days (10 days vs. 15 days, p<0.01) and accelerate CRS resolution by 5 days (6 days vs. 12 days, p<0.001). These findings suggest that TPE may be a valuable adjunctive therapy in the treatment of COVID-19, particularly when initiated early in the course of illness. However, further studies with larger sample sizes and longer follow-up periods are needed to confirm these results and establish the optimal timing and dosing of TPE for COVID-19 treatment.
# Some key findings from the provided abstracts include:
#
# * Improved overall survival: TPE was associated with a significantly higher overall survival rate at 28 days compared to standard care (91.1% vs. 61.5%, p<0.001).
# * Reduced duration of hospitalization: TPE was found to reduce the median duration of hospitalization by 5 days (10 days vs. 15 days, p<0.01).
# * Accelerated resolution of cytokine storm: TPE was associated with a significantly faster resolution of CRS, with a median duration of 6 days compared to 12 days in the standard care group (p<0.001).
# * Mortality reduction: Initiating TPE within the first 12 days of illness was associated with a significantly lower mortality rate (0% vs. 17.9%, p=0.0045).
#
# Some numerical values or statistical information provided in the abstracts include:
#
# * Overall survival rate at 28 days: 91.1% (p<0.001)
# * Duration of hospitalization: 10 days (p<0.01)
# * CRS resolution time: 6 days (p<0.001)
# * Mortality rate: 5% (n = 28)
# * Hazard ratio for mortality: 0.0045 (p=0.0045)
#
# Please note that these findings are based on the abstracts provided and may not reflect the full range of results from the original studies.
# 2
# A meta-analysis of 31 abstracts from medical fields related to COVID-19 found that the use of plasma exchange (PE) was associated with improved outcomes in critically ill patients. The analysis showed that patients who received PE had higher extubation rates, lower mortality rates at 14 and 28 days post-treatment, and improved laboratory and ventilatory parameters compared to those who did not receive PE. However, the sample size was small, and the study had limited power to draw definitive conclusions. Further research is needed to confirm these findings and establish the efficacy of PE in COVID-19 treatment.
# 3
# The provided abstracts highlight the importance of accurate diagnosis of Pseudoprogression (PsP) or radiation necrosis (RN) after cranial radiotherapy, which can be challenging for even experienced neuroradiologists. The studies aimed to evaluate the diagnostic accuracy of Magnetic Resonance Imaging (MRI) based Contrast Clearance Analysis (CCA) in this clinical setting. The results showed that CCA had an accuracy of 0.84 (95% CI 0.67-0.95) in predicting the histological result, with a sensitivity and specificity of 0.93 (95% CI 0.66-1.00) and 0.78 (95% CI 0.52-0.94), respectively. The accuracy was higher in metastases patients compared to primary brain tumor patients (0.94 vs 0.85, p=0.04). These findings suggest that CCA is a useful tool in differentiating between PsP/RN and progressive disease (PD) after cranial radiotherapy, with potential implications for patient management and treatment strategies. However, further studies with larger sample sizes are needed to confirm these results and establish the optimal cutoff values for CCA.
# 4
# Based on the provided abstracts, a meta-analysis was conducted to summarize the key findings and provide numerical values or statistical information for specific observations that are commonly reported. The abstracts were analyzed for the accuracy of radiomics signature for distinguishing radiation necrosis (RN) from true progression (TP) after stereotactic radiosurgery (SRS) for brain metastases (BM). The results showed that the radiomics signature had a high accuracy in distinguishing RN from TP, with a sensitivity of 0.85 (95% CI 0.71-0.94) and a specificity of 0.82 (95% CI 0.67-0.92). The area under the receiver operating characteristic curve (AUC) was 0.91 (95% CI 0.82-0.97). The accuracy was higher in brain metastases patients after radiosurgical treatment compared to primary brain tumor patients, with an odds ratio of 3.2 (95% CI 1.2-8.5). The study concluded that the radiomics signature is a useful tool for distinguishing RN from TP after SRS for BM, with high accuracy and specificity.  The study also found that the accuracy was higher in brain metastases patients after radiosurgical treatment compared to primary brain tumor patients.
# 5
# The provided abstracts contain a significant amount of information on the comparison of radiation-induced necrosis (RN) and tumor recurrence (TP) after gamma knife radiosurgery for intracranial metastases. The abstracts highlight several radiomics features that show promising trends between the two groups, including neighborhood grey tone difference matrix (NGTDM) texture strength, NGTDM coarseness, grey level run length matrix (GLRLM) grey level nonuniformity, and GLRLM run percentage. Additionally, the abstracts mention the use of IsoSVM model for classification, which showed sensitivity and specificity ranging from 50% to 100% in different datasets. Overall, the abstracts suggest that radiomics features may be useful for differentiating RN and TP after gamma knife radiosurgery, although further studies with larger datasets are needed to optimize and validate the model.  Key Findings:  * NGTDM texture strength and NGTDM coarseness showed significant differences between RN and TP. * The IsoSVM model showed sensitivity and specificity ranging from 50% to 100% in different datasets. * The model performed better when trained with 4 T1c features showing similar trends between two datasets. * The model showed inferior performance in the validation dataset due to smaller sample size and class imbalance. * Multivoxel proton magnetic resonance spectroscopy (MRS) was used for differentiation of radiation-induced necrosis and tumor recurrence after gamma knife radiosurgery for intracranial metastases in 33 consecutive cases.  Statistical Information:  * P-value for NGTDM texture strength and NGTDM coarseness: 0.06 and 0.07, respectively. * Sensitivity and specificity of IsoSVM model in different datasets: 50-100%. * Number of RN and TP cases in the validation dataset: 15 and 18, respectively. * Mean and standard deviation of MRS signals in RN and TP groups: not provided.
# 6
# Based on the provided abstracts, the following key findings were identified: 1. Differentiation of radiation-induced necrosis and tumor recurrence after gamma knife radiosurgery for intracranial metastases can be achieved using multivoxel proton MRS. 2. The average time to appearance of symptoms after radiosurgery was found to be 9.3 ± 4.9 months. 3. Metabolic imaging defined four types of lesions: pure tumor recurrence, partial tumor recurrence, radiation-induced tumor necrosis, and radiation-induced necrosis of the peritumoral brain. 4. Proton MRS-based diagnosis was confirmed histologically in all surgically treated patients. 5. The clinical, radiologic, or radiosurgical parameters did not show a statistically significant association with the type of lesion. 6. The model was able to predict the etiology of enhancing lesions following SRS for BM with a high degree of accuracy.
# Some numerical values or statistical information that are commonly reported in the provided abstracts include:  * The average time to appearance of symptoms after radiosurgery (9.3 ± 4.9 months) * The number of patients with pure tumor recurrence (11 cases) and partial tumor recurrence (11 cases) * The number of patients with radiation-induced tumor necrosis (10 cases) and radiation-induced necrosis of the peritumoral brain (1 case) * The number of surgically treated patients for whom proton MRS-based diagnosis was confirmed histologically (7 cases) * The degree of accuracy with which the model was able to predict the etiology of enhancing lesions following SRS for BM (high degree of accuracy)
# 7
# The present meta-analysis aimed to summarize the findings of various abstracts related to the prediction of etiology of enhancing lesions following stereotactic radiosurgery (SRS) for brain metastasis (BM). A total of 73 patients with 78 BM were included in the analysis, and the results showed that the biophysical model used to differentiate radiation necrosis (RN) from tumor progression had a moderate predictive ability. The model estimated tumor cell proliferation rate and diffusion coefficients based on fitting areas of post-contrast T1-weighted MR enhancement observed during serial imaging time points. The model was then used to calculate mass effect due to the mechanical stress field incurred during lesion expansion. The Dice similarity coefficient was used to quantify the similarity of the model-estimated stress field with the edema front visualized in FLAIR imaging. The results showed that the model-estimated stress field had a moderate correlation with the edema front (Dice similarity coefficient = 0.63, 95% CI: 0.47 – 0.75, p = 0.002). Additionally, the model was able to differentiate between RN and tumor progression with an area under the receiver operating characteristic curve (AUC) of 0.73 (95% CI: 0.61 – 0.85, p = 0.0009). However, the model had a low sensitivity (43%) and specificity (64%) in differentiating between RN and tumor progression using standard radiographic morphometric analysis. The present study highlights the potential of the biophysical model for predicting the etiology of enhancing lesions following SRS for BM and provides insights into the underlying mechanisms of RN and tumor progression.
# 8
# treatment decisions in 144 patients, including 53 with BM. The TRAMs identified 74% of BMs as progressing, with an AUC of 0.81 (95% CI: 0.73 – 0.88) for differentiating progressing from stable BMs. The median time to progression was 4.5 months (range: 1.5 – 12.5), and the median survival time for progressors was 12.5 months (range: 5.5 – 24.5). Sensitivity and specificity for differentiating progressing BMs were 81% and 85%, respectively. Conclusions/Discussion: The TRAMs demonstrated excellent accuracy for differentiating progressing BMs, significantly improving patient management in conventional/combined treatments.
# 9
# The present meta-analysis aimed to summarize the key findings from a collection of abstracts related to various medical fields, including oncology, neurology, and cardiology. The included abstracts reported numerical values or statistical information for specific observations commonly reported in the provided abstracts. Overall, the meta-analysis found that the use of TRAMs in brain tumor management resulted in improved patient management, with higher sensitivity and specificity compared to conventional MRI. Additionally, the TRAMs were found to be effective in differentiating tumor and non-tumor tissues, and in detecting residual tumors post-surgery. The study also showed that the BEV treatment resulted in significant reduction in tumor volumes, and that the TRAMs may provide additional sensitivity to response to combined BEV-RT.  Key Findings:  • TRAMs showed higher sensitivity and specificity compared to conventional MRI in brain tumor management. • TRAMs were effective in differentiating tumor and non-tumor tissues. • TRAMs detected residual tumors post-surgery with higher accuracy than conventional MRI. • BEV treatment resulted in significant reduction in tumor volumes. • TRAMs may provide additional sensitivity to response to combined BEV-RT.  Statistical Information:  • Sensitivity and specificity of TRAMs: 90% (95% CI: 80-95%) and 85% (95% CI: 75-90%), respectively. • Accuracy of TRAMs in detecting residual tumors post-surgery: 85% (95% CI: 75-90%). • Mean reduction in tumor volumes with BEV treatment: 58% (95% CI: 48-68%). • Correlation coefficient between initial tumor volumes and response to BEV: r = 0.25 (p = 0.04).
# 10
# The provided abstracts highlight the potential of various medical imaging techniques for improving the diagnosis and treatment of various medical conditions. The studies included in this meta-analysis focus on the use of magnetic resonance imaging (MRI) for brain tumor diagnosis and treatment response assessment, as well as the detection of residual tumors after surgery. The results of these studies suggest that MRI-based techniques can provide additional sensitivity to response to combined MRI-based treatments, such as BEV-RT. The validation of these techniques using histology-confirmed tumor tissues demonstrates their accuracy in differentiating between tumor and non-tumor tissues. The studies also highlight the potential for these techniques to be used for management of patients with various types of tumors after various treatments, including surgery, chemoradiation, radiation treatments, and switch to Avastin. Overall, these findings suggest that MRI-based techniques have the potential to improve the diagnosis and treatment of brain tumors and other medical conditions.  Numerical values or statistical information commonly reported in the provided abstracts include:  * Sensitivity and specificity of MRI-based techniques for tumor detection and response assessment, ranging from 94% to 100%. * Number of patients included in each study, ranging from 51 to 149. * Percentage of patients who underwent surgery, ranging from 67% to 100%. * Types of treatments used in each study, including surgery, chemoradiation, radiation treatments, and switch to Avastin. * Duration of follow-up, ranging from several weeks to several months. * Rate of treatment change based on MRI-based techniques, ranging from 67% to 164%. * Detection of residual tumors after surgery using MRI-based techniques, with a detection rate ranging from 70% to 100%.
# 11
# The current meta-analysis aimed to summarize the key findings of a collection of abstracts related to medical fields, including oncology, neurology, and radiology. The abstracts provided valuable information on the use of CEST imaging for differentiating radiation necrosis from tumor progression in patients with brain metastases. The study found that CEST metrics, such as APT, MT, MTR, and NOEMTR, were able to differentiate between radiation necrosis and tumor progression with high accuracy. The best separation was obtained by NOEMTR, with a mean difference of 8.9% ± 0.9% between necrosis and progression. These findings suggest that CEST imaging may be a useful tool for differentiating radiation necrosis from tumor progression in patients with brain metastases.  The meta-analysis also found that the agreement between pre-surgical CEST maps and histology was excellent, indicating that these maps may be further applied for planning high precision procedures such as biopsies, resections, SRS and iMRT.  The study highlights the importance of CEST imaging in the differential diagnosis of brain metastases, particularly in the context of SRS treatment.  The results of this study have important implications for the diagnosis and treatment of brain metastases, and may lead to further research and clinical applications of CEST imaging in this field.  The study also emphasizes the need for further research to validate these findings and to determine the optimal CEST metrics for differentiating radiation necrosis from tumor progression in different patient populations.  Overall, the study provides valuable insights into the use of CEST imaging for differentiating radiation necrosis from tumor progression in patients with brain metastases, and highlights the potential of this modality for improving diagnosis and treatment in this field.
# 12
# Radiation necrosis and tumor progression are two common complications of cancer treatment, particularly in the brain. This meta-analysis aims to summarize the key findings of various studies that have investigated the diagnostic accuracy of magnetic resonance imaging (MRI) techniques for differentiating radiation necrosis from tumor progression in brain metastases.
#
# A comprehensive literature search was conducted in major scientific databases, including PubMed, Scopus, and Web of Science, to identify studies that have investigated the diagnostic accuracy of MRI techniques for differentiating radiation necrosis from tumor progression in brain metastases. A total of 15 studies were included in this meta-analysis, which reported the diagnostic accuracy of various MRI techniques, including diffusion-weighted imaging (DWI), fluid-attenuated inversion recovery (FLAIR), and dynamic susceptibility contrast (DSC) MRI.
#
# The results of these studies showed that DSC MRI had the highest diagnostic accuracy for differentiating radiation necrosis from tumor progression, with a sensitivity of 86.6% and a specificity of 90.9%. FLAIR MRI had a sensitivity of 73.3% and a specificity of 85.7%, while DWI MRI had a sensitivity of 66.7% and a specificity of 80.0%. The pooled diagnostic accuracy of DSC MRI was calculated to be 90.4% (95% CI: 84.3-96.5%).
#
# Subgroup analysis revealed that DSC MRI had higher diagnostic accuracy in differentiating radiation necrosis from tumor progression in brain metastases compared to primary brain tumors (p = 0.006). Additionally, DSC MRI had higher diagnostic accuracy in differentiating radiation necrosis from tumor progression in lesions with larger sizes (p = 0.002).
#
# In conclusion, this meta-analysis suggests that DSC MRI is the most accurate MRI technique for differentiating radiation necrosis from tumor progression in brain metastases, with a pooled diagnostic accuracy of 90.4% (95% CI: 84.3-96.5%). Further research is warranted to validate these findings and to determine the optimal MRI technique for differentiating radiation necrosis from tumor progression in brain metastases.
#
# The following are the key findings of the individual studies included in this meta-analysis:
#
# 1. DSC MRI had the highest diagnostic accuracy for differentiating radiation necrosis from tumor progression in brain metastases, with a sensitivity of 86.6% and a specificity of 90.9% (Kim et al., 2018).
#
# 2. FLAIR MRI had a sensitivity of 73.3% and a specificity of 85.7% for differentiating radiation necrosis from tumor progression in brain metastases (Wang et al., 2017).
#
# 3. DWI MRI had a sensitivity of 66.7% and a specificity of 80.0% for differentiating radiation necrosis from tumor progression in brain metastases (Zhang et al., 2016).
#
# 4. Subgroup analysis revealed that DSC MRI had higher diagnostic accuracy in differentiating radiation necrosis from tumor progression in brain metastases compared to primary brain tumors (p = 0.006) (Kim et al., 2018).
#
# 5. DSC MRI had higher diagnostic accuracy in differentiating radiation necrosis from tumor progression in lesions with larger sizes (p = 0.002) (Kim et al., 2018).
#
# In conclusion, this meta-analysis suggests that DSC MRI is the most accurate MRI technique for differentiating radiation necrosis from tumor progression in brain metastases, with a pooled diagnostic accuracy of 90.4% (95% CI: 84.3-96.5%). Further research is warranted to validate these findings and to determine the optimal MRI technique for differentiating radiation necrosis from tumor progression in brain metastases.
#
# Note: The above results are based on the information provided in the abstracts and may not reflect the complete find
# 13
# The present meta-analysis aimed to summarize the key findings of various medical fields related to the use of magnetic resonance imaging (MRI) perfusion techniques for differential diagnosis of tumor recurrence and radiation necrosis after radiosurgery. A systematic search of major scientific databases yielded a total of 30 abstracts that met the inclusion criteria. The abstracts were analyzed for the following information: (1) the type of MRI technique used (e.g., DCE-MRI, T1-weighted MRI, etc.); (2) the population studied (e.g., brain tumor patients, breast cancer patients, etc.); (3) the diagnostic criteria used to differentiate tumor recurrence and radiation necrosis; (4) the statistical analysis used to evaluate the relationship between MRI perfusion parameters and the diagnosis of tumor recurrence or radiation necrosis; and (5) the numerical values or statistical information reported for specific observations. The results of the meta-analysis showed that the most commonly used MRI technique was DCE-MRI (80% of abstracts), followed by T1-weighted MRI (17%). The population studied was predominantly brain tumor patients (63% of abstracts), followed by breast cancer patients (17%). The diagnostic criteria used to differentiate tumor recurrence and radiation necrosis were primarily based on clinical and radiologic findings (87% of abstracts), with the use of MRI perfusion parameters (13% of abstracts). The statistical analysis used to evaluate the relationship between MRI perfusion parameters and the diagnosis of tumor recurrence or radiation necrosis included point-biserial correlation coefficient (50% of abstracts) and receiver operating characteristic (ROC) analysis (37% of abstracts). The numerical values or statistical information reported for specific observations included the correlation coefficients (range: 0.27-0.88) and area under the ROC curve (range: 0.63-1.00). The present meta-analysis demonstrated that MRI perfusion techniques, particularly DCE-MRI, can provide valuable information for differential diagnosis of tumor recurrence and radiation necrosis after radiosurgery. However, further research is needed to validate these findings and to determine the optimal MRI perfusion parameters for this purpose.
# 14
# The present meta-analysis aimed to summarize the key findings of various medical fields related to the use of magnetic resonance imaging (MRI) in the assessment of treatment response in cancer patients. A total of 25 abstracts were included in the analysis, which were published between 2010 and 2022. The abstracts were categorized into different medical fields, including brain cancer, breast cancer, lung cancer, and others. The main findings of the meta-analysis are as follows: 1. Brain cancer: MRI can accurately assess treatment response in brain cancer patients. The use of contrast-enhanced MRI can detect changes in tumor size and enhancement pattern, which can be used to predict treatment response. 2. Breast cancer: MRI can help identify breast cancer subtypes and predict response to neoadjuvant chemotherapy. The use of MRI can also detect micrometastases in the axillary lymph nodes. 3. Lung cancer: MRI can help identify early-stage lung cancer and predict response to chemoradiotherapy. The use of MRI can also detect metastases in the mediastinum and abdominal cavity. 4. Others: MRI can be used to assess treatment response in various types of cancer, including pancreatic, prostate, and colorectal cancer. The use of MRI can also detect metastases in unusual locations, such as the bone and soft tissue. 5. Quantitative analysis: The analysis of the abstracts revealed that the use of MRI can provide accurate information on treatment response in cancer patients. The mean accuracy of MRI in predicting treatment response was 85.1%. The analysis also showed that the use of contrast-enhanced MRI can improve the accuracy of treatment response assessment compared to non-contrast MRI. 6. Statistical analysis: The statistical analysis of the abstracts revealed that the use of MRI in treatment response assessment can provide significant improvements in the accuracy of treatment response prediction compared to other imaging modalities. The analysis also showed that the use of MRI can provide better results in the assessment of treatment response in brain cancer compared to other types of cancer. 7. Limitations: The limitations of the meta-analysis include the small sample size of the included abstracts and the variability in the quality of the MRI images used in the studies. The analysis also highlighted the need for further research to validate the use of MRI in treatment response assessment in various medical fields. 8. Conclusion: The present meta-analysis provides evidence that MRI can accurately assess treatment response in cancer patients across various medical fields. The use of MRI can provide accurate information on treatment response and can help improve treatment outcomes in cancer patients. Further research is needed to validate the use of MRI in treatment response assessment and to improve the accuracy of treatment response prediction.
# 15
# The present meta-analysis aimed to summarize the key findings from a collection of abstracts related to medical fields. A total of 13 abstracts were included in the analysis, which covered various medical fields such as neurosurgery, oncology, and cardiology. The abstracts reported various outcomes, including local control rates, progression-free survival, overall survival, and diagnostic accuracy of various imaging modalities.  The results of the meta-analysis showed that the overall local control rate was 90.5% (95% CI: 78.8-97.2), with a median follow-up period of 12 months. The progression-free survival rate was 70.6% (95% CI: 52.9-83.3) at 2 years, and the overall survival rate was 60.8% (95% CI: 45.2-72.5) at 3 years. The diagnostic accuracy of TRAMs in diagnosing radiation effect was found to be high, with a sensitivity of 96.06% (95% CI: 87.4-99.5) and a positive predictive value of 99.2% (95% CI: 91.1-100.0).  The results of the meta-analysis also showed that the mean overall survival was 27.3 months (95% CI: 19.7-34.9), and the radiologic and clinical follow-up showed a good agreement between the clinicoradiologic diagnosis and TRAMs analysis (κ = 0.380).  In conclusion, the present meta-analysis provides evidence for the effectiveness of TRAMs in differentiating radiation effect and persistent tumoral lesions, with a high diagnostic accuracy and good agreement between clinicoradiologic diagnosis and TRAMs analysis.  MP:
#
# Please note that the above abstract is just an example, and the actual abstracts provided may have different findings and statistical information.
# 16
# Based on the provided abstracts, the following key findings can be summarized:
#
# 1. Improved ulcer healing: Several abstracts reported improved ulcer healing with adjunctive hyperbaric oxygen therapy, including MP1, MP2, and MP3. The mean time to healing was significantly shorter in the treatment groups compared to the control groups (p < 0.05).
# 2. Enhanced quality of life: MP1, MP2, and MP3 reported improved health-related quality of life (HRQoL) in patients receiving hyperbaric oxygen therapy. The mean HRQoL score increased significantly in the treatment groups compared to the control groups (p < 0.05).
# 3. Reduced risk of limb-threatening complications: MP1 and MP2 reported a reduced risk of limb-threatening complications in patients receiving hyperbaric oxygen therapy, such as amputation. The risk of amputation was significantly lower in the treatment groups compared to the control groups (p < 0.05).
# 4. No significant adverse effects: None of the abstracts reported significant adverse effects associated with hyperbaric oxygen therapy, such as hypoxia, tissue damage, or toxicity.
#
# Some specific numerical values or statistical information that can be extracted from the provided abstracts include:
#
# * Time to healing: MP1 reported a mean time to healing of 8.5 ± 2.8 weeks in the treatment group and 14.5 ± 4.3 weeks in the control group (p < 0.05).
# * HRQoL scores: MP1 reported a mean HRQoL score of 29.6 ± 8.8 at baseline and 47.5 ± 12.4 at 1-year follow-up in the treatment group, and 25.8 ± 8.2 at baseline and 40.7 ± 11.9 at 1-year follow-up in the control group (p < 0.05).
# * Risk of amputation: MP1 reported a risk of amputation of 12.5% in the control group and 0% in the treatment group (p < 0.05).
#
# Please note that these are just examples of how the information from the provided abstracts could be summarized and statistically analyzed, and the actual numbers and statistical significance may vary depending on the specific data and results of each abstract.
# 17
# The current meta-analysis aims to summarize the key findings from a collection of abstracts related to the use of hyperbaric oxygen therapy (HBOT) in various medical fields, including diabetic foot ulcers, ischaemic ulcers, and non-healing ulcers. The analysis includes 157 abstracts and provides numerical values or statistical information for specific observations that are commonly reported in the provided abstracts.  Key Findings: 1. HBOT is effective in enhancing the healing of diabetic foot ulcers, with a median decrease in wound area of 100% in the treatment group compared to 52% in the control group (p = 0.027). 2. HBOT may be a cost-effective adjunct to conventional therapy, with potential savings in the total cost of treatment for each patient during the study. 3. HBOT is effective in reducing the need for major amputation in patients with diabetes and chronic foot lesions, with a primary outcome of freedom from meeting the criteria for amputation as assessed by a vascular surgeon. 4. HBOT improves measures of wound healing, including median decrease in wound area and time to healing. 5. HBOT is generally well-tolerated, with minor adverse events reported. 6. Further research is needed to fully understand the efficacy and safety of HBOT in various medical fields.  Numerical Values: 1. Median decrease in wound area in the treatment group: 100% 2. Median decrease in wound area in the control group: 52% (p = 0.027) 3. Number of patients in the treatment group: 80 4. Number of patients in the control group: 77 5. Primary outcome: freedom from meeting the criteria for amputation (p = 0.027) 6. Time to healing: median (interquartile range) in the treatment group: 12 (8-16) weeks, in the control group: 16 (10-20) weeks.  Statistical Information: 1. Odds ratio for freedom from meeting the criteria for amputation: 2.65 (95% CI: 1.33-5.34) 2. P-value for primary outcome: 0.027 3. Mean difference in wound area between groups: 4.8% (95% CI: 2.3-7.3%) 4. Hazard ratio for time to healing: 0.75 (95% CI: 0.60-0.95) 5. Relative risk for major amputation: 0.67 (95% CI: 0.43-1.04) 6. Number needed to treat for freedom from meeting the criteria for amputation: 4.8 (95% CI: 2.8-16.8) 7. Number needed to treat for time to healing: 6.7 (95% CI: 4.2-10.6) 8. Number needed to treat for major amputation: 7.8 (95% CI: 4.4-13.6).
# 18
# The current meta-analysis aimed to summarize the key findings of the provided abstracts related to the effectiveness of hyperbaric oxygen therapy (HBOT) in the management of chronic diabetic foot ulcers (CDFUs). The meta-analysis included 157 patients from 3 studies, with 107 patients randomly assigned to HBOT and 50 to placebo/sham treatment. The primary outcome was the rate of complete healing of the index ulcer at 1-year follow-up. Secondary outcomes included measures of wound healing, such as time to healing, wound size, and infection rates.  The results of the meta-analysis showed that HBOT significantly improved the rate of complete healing of the index ulcer compared to placebo/sham treatment (odds ratio [OR] 0.91, 95% confidence interval [CI] 0.37-2.28, P = 0.846). However, there was no significant difference in the rate of healing between the HBOT and placebo/sham groups for any of the secondary outcomes.  The results of this meta-analysis suggest that HBOT may be effective in improving the rate of complete healing of CDFUs, but further research is needed to determine the optimal duration and frequency of HBOT treatment for this condition. Additionally, the results highlight the need for further investigation into the mechanisms of HBOT in the management of CDFUs.
# 19
# hyperbaric oxygen therapy (HBOT) in the treatment of chronic wounds. The aim of this meta-analysis was to summarize the findings of these studies and provide a comprehensive overview of the current evidence on the use of HBOT in chronic wound healing.  METHODS A systematic search of major databases was conducted to identify studies that investigated the effectiveness of HBOT in the treatment of chronic wounds. Studies were included if they were published in English, examined the use of HBOT in chronic wounds, and provided sufficient data for meta-analysis.  RESULTS A total of 15 studies were included in the analysis, with a combined sample size of 1,110 patients. The studies were published between 2000 and 2022, and the majority were conducted in the United States (n = 8) or Europe (n = 7). The majority of the studies (n = 10) were randomized controlled trials (RCTs), while the remaining 5 were observational studies.  The overall healing rate for the combined studies was 43% (95% CI 33–53%). The healing rate was higher in RCTs (50%, 95% CI 38–62%) compared to observational studies (30%, 95% CI 16–44%). The healing rate also varied depending on the type of wound, with higher healing rates observed in studies of diabetic foot ulcers (DFUs) compared to other types of chronic wounds (e.g., venous ulcers, 25%, 95% CI 14–36%).  The frequency of adverse events was low, with only 2 studies reporting serious adverse events. The most common adverse events were related to HBOT itself, including ear pain, sinus pain, and nausea.  CONCLUSIONS The current evidence suggests that HBOT may be effective in promoting wound healing in patients with chronic wounds, particularly those with DFUs. However, the overall healing rate remains relatively low, and further research is needed to determine the optimal HBOT protocol and patient population for wound healing. Additionally, the results suggest that HBOT may be safe and well-tolerated, with few serious adverse events reported.  MP: This meta-analysis provides a comprehensive overview of the current evidence on the use of HBOT in chronic wound healing. The findings suggest that HBOT may be effective in promoting wound healing, particularly in patients with DFUs. However, further research is needed to determine the optimal HBOT protocol and patient population for wound healing, as well as to explore the potential mechanisms of HBOT in chronic wound healing.  Keywords: hyperbaric oxygen therapy, chronic wounds, wound healing, diabetic foot ulcers, systematic review, meta-analysis.
# 20
# The provided abstracts were analyzed to identify the key findings and statistical information related to wound healing in patients with diabetes and lower-limb ischemia. The abstracts were categorized into three main groups based on the type of treatment: standard wound care, adjunctive hyperbaric oxygen therapy (HBOT), and combined therapy. The primary endpoints analyzed were complete wound healing, amputation rate, and survival rate of tissue. The results are presented in the following table:  Group 1: Standard Wound Care (n = 30)  Complete Wound Healing: 10% (3/30)  Amputation Rate: 0% (0/30)  Survival Rate of Tissue: 70% (21/30)  Group 2: Adjunctive Hyperbaric Oxygen Therapy (HBOT) (n = 20)  Complete Wound Healing: 50% (10/20)  Amputation Rate: 0% (0/20)  Survival Rate of Tissue: 80% (16/20)  Group 3: Combined Therapy (n = 20)  Complete Wound Healing: 60% (12/20)  Amputation Rate: 0% (0/20)  Survival Rate of Tissue: 85% (17/20)  Statistical Analysis: A mixed-effects regression analysis was performed to compare the mean differences in complete wound healing, amputation rate, and survival rate of tissue between the three groups. The results showed that the combination of standard wound care and HBOT resulted in a significantly higher complete wound healing rate (60%, 95% CI: 43-77%) and a significantly lower amputation rate (0%, 95% CI: 0-10%) compared to standard wound care alone (10%, 95% CI: 4-16%). Additionally, the combination of standard wound care and HBOT resulted in a significantly higher survival rate of tissue (85%, 95% CI: 73-97%) compared to standard wound care alone (70%, 95% CI: 55-85%).  Conclusion: The results of this meta-analysis suggest that the combination of standard wound care and HBOT is associated with a higher complete wound healing rate and a lower amputation rate compared to standard wound care alone in patients with diabetic foot ulcers. Further research is needed to confirm these findings and to determine the optimal duration and frequency of HBOT for maximum effectiveness.
# 21
# Based on the provided abstracts, a meta-analysis was conducted to summarize the key findings and provide numerical values or statistical information for specific observations that are commonly reported in the provided abstracts. The abstracts were analyzed for markers of inflammation, glycemic control, amputation rate, survival rate of tissue, and health-related quality of life in patients with diabetic foot ulcers (DFUs).  Key Findings: 1. Markers of inflammation: The majority of abstracts reported significant elevation in markers of inflammation in patients with DFUs, indicating a chronic inflammatory response. (p < 0.05) 2. Glycemic control: Improved glycemic control was observed in patients treated with HBOT, with a significant reduction in hemoglobin A1c levels. (p < 0.05) 3. Amputation rate: The amputation rate was significantly lower in the HBOT group compared to the control group (p < 0.01). 4. Survival rate of tissue: HBOT was found to improve the survival rate of tissue in patients with DFUs, with a significant increase in the number of patients achieving complete wound closure. (p < 0.01) 5. Health-related quality of life: HBOT was associated with improved health-related quality of life in patients with DFUs, as measured by the Medical Outcomes Study 36-Item Short Form. (p < 0.05)  Statistical Information: 1. Inflammation index: The mean inflammation index was significantly higher in the control group compared to the HBOT group (p < 0.01). 2. Blood flow: HBOT was found to significantly improve blood flow in patients with DFUs, with a mean increase in blood flow of 20% in the HBOT group compared to the control group (p < 0.01). 3. Hemoglobin A1c: The mean hemoglobin A1c level was significantly lower in the HBOT group compared to the control group (p < 0.05). 4. Amputation rate: The amputation rate was found to be significantly lower in the HBOT group (5%) compared to the control group (11%) (p < 0.01). 5. Survival rate of tissue: The survival rate of tissue was significantly higher in the HBOT group (80%) compared to the control group (55%) (p < 0.01). 6. Health-related quality of life: The mean health-related quality of life score was significantly higher in the HBOT group (70) compared to the control group (55) (p < 0.05).  In conclusion, HBOT is a promising adjunctive therapy for the treatment of DFUs, improving wound healing, glycemic control, and health-related quality of life. The meta-analysis suggests that at least 20 HBOT sessions are required to be effective.
# 22
# The current meta-analysis aims to summarize the key findings of abstracts related to the use of hyperbaric oxygen therapy (HBOT) in the management of diabetic foot ulcers. A total of 50 abstracts were included in the analysis, with the majority of them (n=35) reporting a significant improvement in wound healing and reduction in amputation rates with HBOT compared to standard therapy. Specifically, the pooled data showed that HBOT resulted in a 57% reduction in major amputation rates (95% CI: 44-69, p<0.0001). Additionally, the analysis found that HBOT was associated with a median of 38.8 sessions, with a range of 10-70 sessions, to achieve significant healing outcomes. The study also found that the use of HBOT was associated with a reduced risk of infection (RR: 0.67, 95% CI: 0.54-0.83, p=0.0003) and a shorter duration of wound healing (median: 12 weeks, IQR: 8-20 weeks, p<0.0001). Overall, the meta-analysis suggests that HBOT is a safe and effective adjunct to standard wound care in the management of diabetic foot ulcers, with a significant reduction in major amputation rates and a shorter duration of wound healing.
# 23
# Based on the provided abstracts, the following key findings were observed:
#
# * Amputation: The risk of major amputation was significantly lower in the treated group compared to the nontreated group (RR = 0.26, 95% CI: 0.08-0.84).
# * Oxygen tension: The transcutaneous oxygen tension significantly increased in the treated group compared to the nontreated group (mean difference = 9.4 mmHg, 95% CI: 2.8-16.0 mmHg).
# * Multivariate analysis: The protective role of s-HBOT was confirmed, and low ankle-brachial index values and high Wagner grade were identified as negative prognostic determinants (OR = 0.084, 95% CI: 0.008-0.821 and OR = 1.715, 95% CI: 1.121-2.626, respectively).
#
# Additionally, statistical information for specific observations commonly reported in the abstracts include:
#
# * Mean age of patients: 60.8 years (range: 42-76 years)
# * Number of patients: 54 (32 in the treated group and 22 in the nontreated group)
# * Follow-up period: 1 year (range: 6-12 months)
# * Mean duration of diabetes: 12.4 years (range: 4-25 years)
# * Mean HbA1c level: 8.4% (range: 6.5-11.0%)
# * Mean Wagner grade: 3.5 (range: 2-4)
#
# Please note that the above summary is based on the provided abstracts, and the information may not be comprehensive or up-to-date. Also, the statistical information is based on the provided abstracts and may not be representative of the entire dataset.
# 24
# The present study aimed to investigate the effectiveness of hyperbaric oxygen therapy in managing diabetic foot ulcers. A total of 100 abstracts from various medical fields were analyzed, and the key findings are summarized below. The study found that hyperbaric oxygen therapy significantly improved the healing rate of diabetic foot ulcers, with 78% of patients in the hyperbaric oxygen group healing completely without surgical intervention compared to 0% in the standard treatment group (P < 0.001). Additionally, the study found that the need for amputation, grafting, or debridement was significantly reduced in the hyperbaric oxygen group compared to the standard treatment group (P < 0.001). The study also found that the duration of hospital stay was significantly shorter in the hyperbaric oxygen group compared to the standard treatment group (P < 0.001). Overall, the study suggests that hyperbaric oxygen therapy is a useful adjunct to standard therapy for the management of diabetic foot ulcers.
# ### Numerical Information:  * Healing rate: 78% in the hyperbaric oxygen group vs. 0% in the standard treatment group (P < 0.001) * Amputation, grafting, or debridement: 2 patients in the hyperbaric oxygen group vs. 3 patients in the standard treatment group (P < 0.001) * Duration of hospital stay: 5 days in the hyperbaric oxygen group vs. 7 days in the standard treatment group (P < 0.001)
# ### Statistical Information:  * Chi-square test: P < 0.001 for healing rate, amputation, grafting, or debridement, and duration of hospital stay  * Student's t-test: P < 0.001 for healing rate and duration of hospital stay
# 25
# Based on the provided abstracts, a meta-analysis abstract can be generated as follows:
#
# Meta-Analysis Abstract:
#
# The present meta-analysis aimed to summarize the key findings from a collection of abstracts related to various medical fields, including dentistry. The abstracts were selected based on their relevance to the topic of clinical performance of dental restorations. The following findings were observed:
#
# 1. Clinical quality and longevity: The abstracts revealed that the clinical quality and longevity of dental restorations vary depending on the type of material used. For example, gold inlays were found to be more durable than ceramic inlays, with a higher percentage of satisfactory ratings at 5 years (92% vs. 8%).
# ...
# 48
# The current meta-analysis aims to summarize the key findings of a collection of abstracts related to various medical fields. The abstracts were analyzed for common themes, patterns, and trends, and statistical information was extracted where possible. The following findings were observed:
#
# 1. Gender differences: Several studies found significant gender differences in the prevalence of various medical conditions, such as depression, anxiety, and cardiovascular disease. For example, one study found that women were more likely to experience depression than men (odds ratio [OR] = 1.53, 95% confidence interval [CI] = 1.24-1.87).
# 2. Socioeconomic factors: Poverty, unemployment, and low education levels were consistently associated with poorer health outcomes, including increased risk of chronic diseases and lower life expectancy. For example, one study found that individuals with lower socioeconomic status had a higher risk of developing type 2 diabetes (OR = 1.27, 95% CI = 1.03-1.57).
# 3. Lifestyle factors: A consistent pattern emerged regarding the impact of lifestyle factors on health outcomes. For example, studies found that smoking, excessive alcohol consumption, and lack of physical activity were associated with increased risk of cardiovascular disease (OR = 1.29, 95% CI = 1.07-1.56).
# 4. Access to healthcare: Barriers to accessing healthcare, such as lack of transportation or long wait times, were found to be associated with worse health outcomes. For example, one study found that individuals with lower levels of education were more likely to experience delays in accessing medical care (OR = 1.16, 95% CI = 1.03-1.32).
# 5. Genetic factors: A few studies explored the role of genetic factors in health outcomes, finding that certain genetic variants were associated with increased risk of certain diseases. For example, one study found that individuals with a specific genetic variant had a higher risk of developing Alzheimer's disease (OR = 1.23, 95% CI = 1.03-1.47).
#
# In conclusion, the current meta-analysis highlights the importance of considering gender, socioeconomic, lifestyle, access to healthcare, and genetic factors when studying health outcomes. These findings have implications for the development of targeted interventions and policies aimed at improving population health.
# 49
# The current meta-analysis aims to summarize the key findings from a collection of abstracts related to medical fields, including psychology, sexual violence, and interventions. The abstracts were selected based on their relevance to the current analysis and their availability. The meta-analysis found that: 1. The prevalence of IPV perpetration was significantly higher among females (10%) compared to males (6%). 2. The relationship between maladaptive personality traits and IPV perpetration varied depending on the level of Dark Tetrad traits. 3. Adversarial sexual attitudes mediated the relationship between maladaptive personality traits and sexual violence. 4. The rate of sexual violence perpetration was significantly higher among national samples (13%) compared to university samples (6%). 5. The structural equation model predicting sexual violence was replicated in both university and national samples. 6. Implementing appropriate interventions in the context of IPV perpetration and sexual violence could have implications for society as a whole. 7. Collecting data in multiple populations is crucial for understanding the prevalence and predictors of sexual violence. 8. Limited prevention efforts may contribute to the spike in sexual violence rates in older, more diverse populations. 9. The findings of this meta-analysis highlight the importance of collecting data on individual differences, such as maladaptive personality traits and adversarial sexual attitudes, as mechanisms underlying IPV perpetration and sexual violence. 10. Future research should continue to explore the complex factors contributing to IPV perpetration and sexual violence, including the role of gender and societal factors.
# 50
# A meta-analysis of 10 studies on the relationship between personality traits and sexual violence found that maladaptive personality traits, such as hostility, eccentricity, and grandiosity, are significant predictors of sexual violence perpetration. The studies included in the analysis ranged in sample size from 439 to 592 participants and were conducted in both university and national populations. The analysis found that adversarial sexual attitudes mediated the relationship between personality traits and sexual violence, with women in the national sample reporting higher rates of sexual violence perpetration than men. The findings suggest that prevention efforts should focus on identifying and addressing maladaptive personality traits and adversarial sexual attitudes in both men and women. Overall, the meta-analysis provides evidence that personality traits are an important factor in sexual violence perpetration and highlights the need for a comprehensive approach to prevention.  Key Findings:  - Maladaptive personality traits are significant predictors of sexual violence perpetration.  - Adversarial sexual attitudes mediate the relationship between personality traits and sexual violence.  - Women in national samples report higher rates of sexual violence perpetration than men.  - Prevention efforts should focus on identifying and addressing maladaptive personality traits and adversarial sexual attitudes in both men and women.  Statistical Information:  - The studies included in the analysis had a combined sample size of 1,038 participants.  - The mean age of participants ranged from 18 to 25 years old.  - The majority of participants (80%) were female.  - The studies used a variety of methods to assess personality traits, including self-report measures and observer ratings.  - The studies used a range of methods to assess sexual violence perpetration, including self-report measures and official records.  - The analysis found a significant effect size (r = 0.45) for the relationship between personality traits and sexual violence perpetration.
#                                            Meta_Paper  \
# 0   MP: Assessment of efficacy of therapeutic plas...
# 1   of Coronavirus disease-2019 (COVID-19). Therap...
# 2   days of illness while it was 17.9% (deaths 5, ...
# 3   MP: BACKGROUND Pseudoprogression (PsP) or radi...
# 4   (95%-CI 0.66–1.00) and 0.78 (95% CI 0.52–0.94)...
# 5   significant difference among baseline characte...
# 6   (MRS) was used for differentiation of radiatio...
# 7   model to predict the etiology of enhancing les...
# 8   CI: 0.61 – 0.85, p = 0.0009, 74% sensitivity a...
# 9   re-RT. Results The TRAMs were validated histol...
# 10  undergoing conventional treatments. Initial ex...
# 11  malignant transformation from treatment effect...
# 12  and radiographic follow-up). The best separati...
# 13  performed by 1,5 Tesla MR scanner. The statist...
# 14  were included as the control group. Semiquanti...
# 15  patients with 130 metastatic brain tumors who ...
# 16  MP: Aims Adjunctive treatment with hyperbaric ...
# 17  patients with ischaemic, non-healing lower-ext...
# 18  was freedom from meeting the criteria for ampu...
# 19  of the index ulcer was achieved in 37 patients...
# 20  complete wound healing or limb salvage in pati...
# 21  markers of inflammation, glycemic control, amp...
# 22  in persons with DFU. Therapy also reduced the ...
# 23  amputation: two below the knee and one above t...
# 24  of healing, and need for amputation, grafting ...
# 25  MP: Purpose: The present follow-up study aimed...
# 26  prospective, clinical split-mouth study. In ea...
# 27  period. Two hundred and twenty-three patients ...
# 28  in performing the restorations rated both kind...
# 29  MP: Objectives Childhood anorexia, among the c...
# 30  problems meet significant challenges. A commer...
# 31  capacitance between the high aspect ratio wire...
# 32  Growth (LHPG) fabricated single crystal fiber ...
# 33  rates slowed down. Furthermore, 16S rRNA gene ...
# 34  showed that tuina was superior to western medi...
# 35  in the treatment group as compared with the co...
# 36  Although the impact from temperature is weaker...
# 37  level in the child of anorexia, so as to revea...
# 38  MP: This study investigated whether dark tetra...
# 39  evaluation and validation process (Chapter 2),...
# 40  narcissism, and Machiavellianism-the "Dark Tri...
# 41  were unique predictors of antisocial behavior ...
# 42  of religious radicalization.  MP: Sadism is a ...
# 43  one profile or two quantitatively different pr...
# 44  and alcohol use, while the same profile based ...
# 45  this examination, it was found that sadism cou...
# 46  a trait of sadism (enjoyment in pain of others...
# 47  to predict criminal attitudes. The results sho...
# 48  is a pending issue in empirical research that ...
# 49  were 109 men and 290 women (age range = 17–33,...
# 50  personality traits predicted adversarial sexua...
#
#                                          Ground Truth  \
# 0   Objective The COVID-19 pandemic continues, and...
# 1   Objective The COVID-19 pandemic continues, and...
# 2   Objective The COVID-19 pandemic continues, and...
# 3   Background Treatment response assessment in pa...
# 4   Background Treatment response assessment in pa...
# 5   Background Treatment response assessment in pa...
# 6   Background Treatment response assessment in pa...
# 7   Background Treatment response assessment in pa...
# 8   Background Treatment response assessment in pa...
# 9   Background Treatment response assessment in pa...
# 10  Background Treatment response assessment in pa...
# 11  Background Treatment response assessment in pa...
# 12  Background Treatment response assessment in pa...
# 13  Background Treatment response assessment in pa...
# 14  Background Treatment response assessment in pa...
# 15  Background Treatment response assessment in pa...
# 16  The present systematic review and meta-analysi...
# 17  The present systematic review and meta-analysi...
# 18  The present systematic review and meta-analysi...
# 19  The present systematic review and meta-analysi...
# 20  The present systematic review and meta-analysi...
# 21  The present systematic review and meta-analysi...
# 22  The present systematic review and meta-analysi...
# 23  The present systematic review and meta-analysi...
# 24  The present systematic review and meta-analysi...
# 25  Objectives The goal of this systemic review an...
# 26  Objectives The goal of this systemic review an...
# 27  Objectives The goal of this systemic review an...
# 28  Objectives The goal of this systemic review an...
# 29  Objectives Childhood anorexia, among the commo...
# 30  Objectives Childhood anorexia, among the commo...
# 31  Objectives Childhood anorexia, among the commo...
# 32  Objectives Childhood anorexia, among the commo...
# 33  Objectives Childhood anorexia, among the commo...
# 34  Objectives Childhood anorexia, among the commo...
# 35  Objectives Childhood anorexia, among the commo...
# 36  Objectives Childhood anorexia, among the commo...
# 37  Objectives Childhood anorexia, among the commo...
# 38  Background Everyday sadism is unique among the...
# 39  Background Everyday sadism is unique among the...
# 40  Background Everyday sadism is unique among the...
# 41  Background Everyday sadism is unique among the...
# 42  Background Everyday sadism is unique among the...
# 43  Background Everyday sadism is unique among the...
# 44  Background Everyday sadism is unique among the...
# 45  Background Everyday sadism is unique among the...
# 46  Background Everyday sadism is unique among the...
# 47  Background Everyday sadism is unique among the...
# 48  Background Everyday sadism is unique among the...
# 49  Background Everyday sadism is unique among the...
# 50  Background Everyday sadism is unique among the...
#
#                                      Processed Output
# 0   The present meta-analysis aimed to summarize t...
# 1   The provided abstracts highlight the potential...
# 2   A meta-analysis of 31 abstracts from medical f...
# 3   The provided abstracts highlight the importanc...
# 4   Based on the provided abstracts, a meta-analys...
# 5   The provided abstracts contain a significant a...
# 6   Based on the provided abstracts, the following...
# 7   The present meta-analysis aimed to summarize t...
# 8   treatment decisions in 144 patients, including...
# 9   The present meta-analysis aimed to summarize t...
# 10  The provided abstracts highlight the potential...
# 11  The current meta-analysis aimed to summarize t...
# 12  Radiation necrosis and tumor progression are t...
# 13  The present meta-analysis aimed to summarize t...
# 14  The present meta-analysis aimed to summarize t...
# 15  The present meta-analysis aimed to summarize t...
# 16  Based on the provided abstracts, the following...
# 17  The current meta-analysis aims to summarize th...
# 18  The current meta-analysis aimed to summarize t...
# 19  hyperbaric oxygen therapy (HBOT) in the treatm...
# 20  The provided abstracts were analyzed to identi...
# 21  Based on the provided abstracts, a meta-analys...
# 22  The current meta-analysis aims to summarize th...
# 23  Based on the provided abstracts, the following...
# 24  The present study aimed to investigate the eff...
# 25  Based on the provided abstracts, a meta-analys...
# 26  90 patients were restored with 90 gold crowns....
# 27  Based on the provided abstracts, a meta-analys...
# 28  The present study aimed to compare the longevi...
# 29  The present meta-analysis aimed to summarize t...
# 30  The present study aims to investigate the effe...
# 31  The present study aims to investigate the key ...
# 32  The present study aimed to summarize the key f...
# 33  Based on the analysis of 28 randomized control...
# 34  Based on the provided abstracts, the following...
# 35  A meta-analysis of 10 abstracts from various m...
# 36  The present meta-analysis aims to summarize th...
# 37  This meta-analysis aims to summarize the key f...
# 38  Based on the provided abstracts, the following...
# 39  Based on the provided abstracts, a meta-analys...
# 40  Based on the provided abstracts, a meta-analys...
# 41  Based on a collection of abstracts from papers...
# 42  Based on the provided abstracts, a meta-analys...
# 43  The present meta-analysis aimed to investigate...
# 44  The present meta-analysis aims to synthesize t...
# 45  The current meta-analysis aims to summarize th...
# 46  The present meta-analysis aims to synthesize t...
# 47  The current meta-analysis aims to summarize th...
# 48  The current meta-analysis aims to summarize th...
# 49  The current meta-analysis aims to summarize th...
# 50  A meta-analysis of 10 studies on the relations...

# %%
df.to_csv("llama2_finetune_consine_similarities.csv")

# %%
for i in range(len(testset['Meta_Paper'])):
    text = f"### {DEFAULT_SYSTEM_PROMPT},### Example Abstracts: {testset['Meta_Paper'][i]}  \n ### Meta-Analysis Abstract: "
    pred = []
    processed_output = summarize(text)
    print(processed_output)
    print("\n\n")
